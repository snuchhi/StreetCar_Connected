# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.figure_factory as ff

# %%
df_bsm_pdx_broadway_try = pd.read_csv('PDX_MULTIPLE/BsmLogMarket_Broadway_07022020_015038.csv', usecols = ['timestamp_verbose','temporaryId','trajectory_signal_group','type','distance_to_stopbar', 'distance_along_path','onmap_status'])

# %%
df_bsm_pdx_market10th_try = pd.read_csv('PDX_MULTIPLE/BsmLogMarket_10th_07022020_015029.csv', usecols = ['timestamp_verbose','temporaryId','trajectory_signal_group','type','distance_to_stopbar', 'distance_along_path','onmap_status'])

# %%
df_bsm_pdx_market11th_try = pd.read_csv('PDX_MULTIPLE/BsmLogMarket_11th_07022020_015033.csv', usecols = ['timestamp_verbose','temporaryId','trajectory_signal_group','type','distance_to_stopbar', 'distance_along_path','onmap_status'])

# %%
df_bsm_pdx_broadway_try
df_bsm_pdx_broadway_try.distance_to_stopbar = pd.to_numeric(df_bsm_pdx_broadway_try.distance_to_stopbar,errors = 'coerce')

# %%
df_bsm_pdx_market10th_try
df_bsm_pdx_market10th_try.distance_to_stopbar = pd.to_numeric(df_bsm_pdx_market10th_try.distance_to_stopbar,errors = 'coerce')

# %%
df_bsm_pdx_market11th_try
df_bsm_pdx_market11th_try.distance_to_stopbar = pd.to_numeric(df_bsm_pdx_market11th_try.distance_to_stopbar,errors = 'coerce')

# %%
#df_bsm_pdx_market11th_try
#df_bsm_pdx_market11th_try.temporaryId = pd.to_numeric(df_bsm_pdx_market11th_try.temporaryId,errors = 'coerce')

# %%
#df_bsm_pdx_market10th_try
#df_bsm_pdx_market10th_try.temporaryId = pd.to_numeric(df_bsm_pdx_market10th_try.temporaryId,errors = 'coerce')

# %%
#df_bsm_pdx_market10th_try
#df_bsm_pdx_market10th_try.temporaryId = pd.to_numeric(df_bsm_pdx_market10th_try.temporaryId,errors = 'coerce')

# %%
df_bsm_pdx_broadway_try_1 = df_bsm_pdx_broadway_try[df_bsm_pdx_broadway_try.trajectory_signal_group == '4']

# %%
df_bsm_pdx_market11th_try_1 = df_bsm_pdx_market11th_try[df_bsm_pdx_market11th_try.trajectory_signal_group == '4']

# %%
df_bsm_pdx_market10th_try_1 = df_bsm_pdx_market10th_try[df_bsm_pdx_market10th_try.trajectory_signal_group == '4']

# %%
df_bsm_pdx_broadway_try_1 = df_bsm_pdx_broadway_try_1[df_bsm_pdx_broadway_try_1.type == 'transit']

# %%
df_bsm_pdx_market10th_try_1 = df_bsm_pdx_market10th_try_1[df_bsm_pdx_market10th_try_1.type == 'transit']

# %%
df_bsm_pdx_market11th_try_1 = df_bsm_pdx_market11th_try_1[df_bsm_pdx_market11th_try_1.type == 'transit']

# %%
df_bsm_pdx_broadway_try_1
# Out:
#                timestamp_verbose  temporaryId     type  \
# 0     2020-07-02 02:02:47.890255           26  transit
# 1     2020-07-02 02:02:48.089968           26  transit
# 2     2020-07-02 02:02:48.302083           26  transit
# 3     2020-07-02 02:02:48.502419           26  transit
# 4     2020-07-02 02:02:48.603441           26  transit
# ...                          ...          ...      ...
# 9576  2020-07-02 02:29:20.954163         1217  transit
# 9577  2020-07-02 02:29:21.153199         1217  transit
# 9578  2020-07-02 02:29:21.263455         1217  transit
# 9579  2020-07-02 02:29:21.463856         1217  transit
# 9580  2020-07-02 02:29:21.674132         1217  transit
#
#      trajectory_signal_group  distance_to_stopbar  distance_along_path  \
# 0                          4               172.78             0.000000
# 1                          4               170.33             2.459141
# 2                          4               167.88             4.883816
# ...

# %%
df_groups_try_1 = df_bsm_pdx_broadway_try_1.groupby(['temporaryId','trajectory_signal_group']).first().reset_index()

# %%
df_groups_try_2 = df_bsm_pdx_market10th_try_1.groupby(['temporaryId','trajectory_signal_group']).first().reset_index()

# %%
df_groups_try_3 = df_bsm_pdx_market11th_try_1.groupby(['temporaryId','trajectory_signal_group']).first().reset_index()

# %%
df_groups_try_1['groupbydistance'] = df_groups_try_1['onmap_status'].cumsum()

# %%
df_groups_try_2['groupbydistance'] = df_groups_try_2['onmap_status'].cumsum()

# %%
df_groups_try_3['groupbydistance'] = df_groups_try_3['onmap_status'].cumsum()

# %%
df_groups_try_1.distance_along_path = df_groups_try_1.distance_along_path.astype(float)

# %%
df_groups_try_2.distance_along_path = df_groups_try_2.distance_along_path.astype(float)

# %%
df_groups_try_3.distance_along_path = df_groups_try_3.distance_along_path.astype(float)

# %%
df_groups_try_1['distance_along_path'] = df_groups_try_1['distance_to_stopbar'] * -1

# %%
df_groups_try_2['distance_along_path'] = df_groups_try_2['distance_to_stopbar'] * -1

# %%
df_groups_try_3['distance_along_path'] = df_groups_try_3['distance_to_stopbar'] * -1

# %%
df_bsm_pdx_broadway_try_1 = df_bsm_pdx_broadway_try_1.merge(df_groups_try_1, on=['timestamp_verbose','temporaryId','trajectory_signal_group','type','distance_to_stopbar'], how='outer')

# %%
df_bsm_pdx_market10th_try_1 = df_bsm_pdx_market10th_try_1.merge(df_groups_try_2, on=['timestamp_verbose','temporaryId','trajectory_signal_group','type','distance_to_stopbar'], how='outer')

# %%
#df_bsm_pdx_market11th_try_1 = df_bsm_pdx_market11th_try_1.merge(df_groups_try_3, on=['timestamp_verbose','temporaryId','trajectory_signal_group','type','distance_to_stopbar'], how='outer')

# %%
df_bsm_pdx_broadway_try_1.columns = ['timestamp_verbose','temporaryId', 'trajectory_signal_group','type', 'distance_to_stopbar', 'distance_along_path', 'onmap_status', 'tmp', 'distance_along_path_change', 'groupbydistance']

# %%
df_bsm_pdx_market10th_try_1.columns = ['timestamp_verbose','temporaryId', 'trajectory_signal_group','type', 'distance_to_stopbar', 'distance_along_path', 'onmap_status', 'tmp', 'distance_along_path_change', 'groupbydistance']

# %%
#df_bsm_pdx_market11th_try_1.columns = ['timestamp_verbose','temporaryId', 'trajectory_signal_group','type', 'distance_to_stopbar', 'distance_along_path', 'onmap_status', 'tmp', 'distance_along_path_change', 'groupbydistance']

# %%
df_bsm_pdx_broadway_try_1.fillna(method='ffill', inplace=True)

# %%
df_bsm_pdx_market10th_try_1.fillna(method='ffill', inplace=True)

# %%
#df_bsm_pdx_market11th_try_1.fillna(method='ffill', inplace=True)

# %%
df_bsm_pdx_broadway_try_1['distance_along_path_change'] = df_bsm_pdx_broadway_try_1['distance_along_path'] + df_bsm_pdx_broadway_try_1['tmp']

# %%
df_bsm_pdx_market10th_try_1['distance_along_path_change'] = df_bsm_pdx_market10th_try_1['distance_along_path'] + df_bsm_pdx_market10th_try_1['tmp']

# %%
df_bsm_pdx_market10th_try_1['distance_along_path_change'] = df_bsm_pdx_market10th_try_1['distance_along_path'] + (-240)

# %%
df_bsm_pdx_broadway_try_1.drop('tmp', axis=1, inplace=True)

# %%
df_bsm_pdx_market10th_try_1.drop('tmp', axis=1, inplace=True)

# %%
#df_bsm_pdx_market11th_try_1.drop('tmp', axis=1, inplace=True)

# %%
df_bsm_id_pdx_street = df_bsm_pdx_broadway_try_1.copy()
df_bsm_id_pdx_street['distance_along_path'] = -80.65
import plotly.express as px
fig_pdx_street = px.line(x=df_bsm_id_pdx_street.timestamp_verbose, y= df_bsm_id_pdx_street.distance_along_path,title = 'Using distance along path')
fig_pdx_street.update_xaxes(rangeslider_visible=True)
# Out:
# <div>
#
#
#             <div id="452bae65-2b2f-4a82-9622-ddaab6a01483" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("452bae65-2b2f-4a82-9622-ddaab6a01483")) {
#                     Plotly.newPlot(
#                         '452bae65-2b2f-4a82-9622-ddaab6a01483',
# ...

# %%
import plotly.graph_objs as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_bsm_id_pdx_street.timestamp_verbose, y= df_bsm_id_pdx_street.distance_along_path,
                        mode = 'lines', name = 'lines', line=dict(color='firebrick', width=3)))
# Out:
# <div>
#
#
#             <div id="3a8ec856-3fe2-455a-8d40-b2910af75a6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a8ec856-3fe2-455a-8d40-b2910af75a6e")) {
#                     Plotly.newPlot(
#                         '3a8ec856-3fe2-455a-8d40-b2910af75a6e',
# ...

# %%
import plotly.express as px
#fig_pdx_street = px.line(x=df_bsm_id_pdx_street.timestamp_verbose, y= df_bsm_id_pdx_street.distance_along_path,title = 'Using distance along path')
#fig_pdx_street.update_xaxes(rangeslider_visible=True) 
fig = px.line(df_bsm_pdx_broadway_try_1, x='timestamp_verbose', y='distance_along_path_change', color='temporaryId')
fig.show()
fig.add_trace(go.Scatter(x=df_bsm_id_pdx_street.timestamp_verbose, y= df_bsm_id_pdx_street.distance_along_path,
                        mode = 'lines', name = 'lines', line=dict(color='firebrick', width=3)))
# Out:
# <div>
#
#
#             <div id="f405a0e7-7f5b-4ad0-b108-4b2fc7cbe20f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f405a0e7-7f5b-4ad0-b108-4b2fc7cbe20f")) {
#                     Plotly.newPlot(
#                         'f405a0e7-7f5b-4ad0-b108-4b2fc7cbe20f',
# ...

# %%
import plotly.express as px
#fig_pdx_street = px.line(x=df_bsm_id_pdx_street.timestamp_verbose, y= df_bsm_id_pdx_street.distance_along_path,title = 'Using distance along path')
#fig_pdx_street.update_xaxes(rangeslider_visible=True) 
fig_market = px.line(df_bsm_pdx_market10th_try_1, x='timestamp_verbose', y='distance_along_path_change', color='temporaryId')
fig_market.show()
# Out:
# <div>
#
#
#             <div id="996103d7-4049-4598-92b5-be69f65978c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("996103d7-4049-4598-92b5-be69f65978c3")) {
#                     Plotly.newPlot(
#                         '996103d7-4049-4598-92b5-be69f65978c3',
# ...

# %%
df_bsm_pdx_market10th_try_1
# Out:
#                timestamp_verbose  temporaryId trajectory_signal_group type  \
# 0     2020-07-02 02:02:42.067329           26                 transit    4
# 1     2020-07-02 02:02:42.266667           26                 transit    4
# 2     2020-07-02 02:02:42.475492           26                 transit    4
# 3     2020-07-02 02:02:42.675253           26                 transit    4
# 4     2020-07-02 02:02:42.885692           26                 transit    4
# ...                          ...          ...                     ...  ...
# 1160  2020-07-02 02:29:12.330489         1234                 transit    4
# 1161  2020-07-02 02:29:12.529773         1234                 transit    4
# 1162  2020-07-02 02:29:12.736944         1234                 transit    4
# 1163  2020-07-02 02:29:12.839110         1234                 transit    4
# 1164  2020-07-02 02:29:13.038987         1234                 transit    4
#
#       distance_to_stopbar  distance_along_path  onmap_status  \
# ...

# %%
colors = {'red': 'rgb(255,0,0)',
          'red': 'rgb(255,0,0)',
          'green': 'rgb(0,128,0)',
          'green': 'rgb(0,100,0)',
          'yellow': 'rgb(255,165,0)',
          'yellow': 'rgb(255,255,0)',
          }

# %%
df_spat_v4_pdx_market_broadway = pd.read_csv('PDX_MULTIPLE/spatLog_Market_Broadway_07022020_015038.csv')

# %%
df_spat_v4_pdx_market_broadway['change_v4'] = ( 
    df_spat_v4_pdx_market_broadway.v4_currState != df_spat_v4_pdx_market_broadway.v4_currState.shift()).astype(int)

# %%
df_spat_v4_pdx_market_broadway_change = df_spat_v4_pdx_market_broadway.loc[df_spat_v4_pdx_market_broadway['change_v4'] != 0]

# %%
df_spat_v4_pdx_market_broadway_change.reset_index(drop=True, inplace=True)

# %%
df_spat_v4_pdx_market_10th = pd.read_csv('PDX_MULTIPLE/spatLog_Market_10th_07022020_015029.csv')

# %%
df_spat_v4_pdx_market_11th = pd.read_csv('PDX_MULTIPLE/spatLog_Market_11th_07022020_015033.csv')

# %%
df_spat_v4_pdx_market_10th['change_v4'] = ( 
    df_spat_v4_pdx_market_10th.v4_currState != df_spat_v4_pdx_market_10th.v4_currState.shift()).astype(int)

# %%
df_spat_v4_pdx_market_11th['change_v4'] = ( 
    df_spat_v4_pdx_market_11th.v4_currState != df_spat_v4_pdx_market_11th.v4_currState.shift()).astype(int)

# %%
df_spat_v4_pdx_market_10th_change = df_spat_v4_pdx_market_10th.loc[ df_spat_v4_pdx_market_10th['change_v4'] != 0]

# %%
df_spat_v4_pdx_market_11th_change =  df_spat_v4_pdx_market_11th.loc[ df_spat_v4_pdx_market_11th['change_v4'] != 0]

# %%
df_spat_v4_pdx_market_10th_change.reset_index(drop=True, inplace=True)

# %%
df_spat_v4_pdx_market_11th_change.reset_index(drop=True, inplace=True)

# %%
N = len(df_spat_v4_pdx_market_broadway_change)
df_spat_v4_pdx_market_broadway_change['end_timestamp'] = df_spat_v4_pdx_market_broadway_change.loc[1:N]['log_timestamp_verbose']
df_spat_v4_pdx_market_broadway_change['end_timestamp'] = df_spat_v4_pdx_market_broadway_change['end_timestamp'].shift(-1)

# %%
N = len(df_spat_v4_pdx_market_10th_change)
df_spat_v4_pdx_market_10th_change['end_timestamp'] = df_spat_v4_pdx_market_10th_change.loc[1:N]['log_timestamp_verbose']
df_spat_v4_pdx_market_10th_change['end_timestamp'] = df_spat_v4_pdx_market_10th_change['end_timestamp'].shift(-1)

# %%
N = len(df_spat_v4_pdx_market_11th_change)
df_spat_v4_pdx_market_11th_change['end_timestamp'] = df_spat_v4_pdx_market_11th_change.loc[1:N]['log_timestamp_verbose']
df_spat_v4_pdx_market_11th_change['end_timestamp'] = df_spat_v4_pdx_market_11th_change['end_timestamp'].shift(-1)

# %%
df_spat_v4_pdx_market_broadway_change = df_spat_v4_pdx_market_broadway_change[['intersectionId','log_timestamp_verbose', 'end_timestamp' ,'v4_currState']].copy()
df_spat_v4_pdx_market_broadway_change.columns = ['Task','Start','Finish','Resource']

# %%
df_spat_v4_pdx_market_10th_change = df_spat_v4_pdx_market_10th_change[['intersectionId','log_timestamp_verbose', 'end_timestamp' ,'v4_currState']].copy()
df_spat_v4_pdx_market_10th_change.columns = ['Task','Start','Finish','Resource']

# %%
df_spat_v4_pdx_market_11th_change = df_spat_v4_pdx_market_11th_change[['intersectionId','log_timestamp_verbose', 'end_timestamp' ,'v4_currState']].copy()
df_spat_v4_pdx_market_11th_change.columns = ['Task','Start','Finish','Resource']

# %%
df_spat_pdx_final = pd.concat([df_spat_v4_pdx_market_11th_change,df_spat_v4_pdx_market_10th_change,df_spat_v4_pdx_market_broadway_change], ignore_index=True)

# %%
df_spat_pdx_final.loc[df_spat_pdx_final.Task == 34108, 'Task'] = 'Market&Broadway'

# %%
df_spat_pdx_final.loc[df_spat_pdx_final.Task == 35925, 'Task'] = 'Market&10th'

# %%
df_spat_pdx_final.loc[df_spat_pdx_final.Task == 36447, 'Task'] = 'Market&11th'

# %%
groupedtask = [0,-160,-240]

# %%
import plotly.figure_factory as ff
from plotly.offline import iplot
fig_pdx_gantt_multiple = plt.figure(figsize=(20,10))
fig_pdx_gantt_multiple = ff.create_gantt(df_spat_pdx_final, colors=colors, index_col='Resource', show_colorbar=False,
                      group_tasks=True,groupedtasks_dist = groupedtask,title='TimeSpace Diagram',
                     showgrid_x=True,showgrid_y=True,bar_width=10, height = 500)
fig_pdx_gantt_multiple['layout']['yaxis'].update(range=[-500,200])
fig_pdx_gantt_multiple['layout']['yaxis'].update(tickvals=[0,-160,-240])
fig_pdx_gantt_multiple.update_xaxes(rangeslider_visible=True) 
fig_pdx_gantt_multiple.update_layout(showlegend=True)
for tr in fig.data:
    fig_pdx_gantt_multiple.add_trace(tr)
for tr in fig_market.data:
    fig_pdx_gantt_multiple.add_trace(tr)
fig_pdx_gantt_multiple.show()
# Out:
# <div>
#
#
#             <div id="bc528be2-600b-463e-90bd-cf2261324241" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc528be2-600b-463e-90bd-cf2261324241")) {
#                     Plotly.newPlot(
#                         'bc528be2-600b-463e-90bd-cf2261324241',
# ...

# %%
#TRAVELTIME FOR THE STREETCARS

# %%
columns = ['id','start_time', 'end_time', 'difference']
df_traveltime = pd.DataFrame(columns=columns)
df_traveltime = df_traveltime.fillna(0)

# %%
def first_last(df):
    return df.iloc[[0, -1]]

# %%
df_traveltime = df_bsm_pdx_broadway_try_1.groupby('temporaryId', group_keys=False).apply(first_last)

# %%
df_bsm_pdx_broadway_try_1
# Out:
#                timestamp_verbose  temporaryId trajectory_signal_group type  \
# 0     2020-07-02 02:02:47.890255           26                 transit    4
# 1     2020-07-02 02:02:48.089968           26                 transit    4
# 2     2020-07-02 02:02:48.302083           26                 transit    4
# 3     2020-07-02 02:02:48.502419           26                 transit    4
# 4     2020-07-02 02:02:48.603441           26                 transit    4
# ...                          ...          ...                     ...  ...
# 1963  2020-07-02 02:29:20.954163         1217                 transit    4
# 1964  2020-07-02 02:29:21.153199         1217                 transit    4
# 1965  2020-07-02 02:29:21.263455         1217                 transit    4
# 1966  2020-07-02 02:29:21.463856         1217                 transit    4
# 1967  2020-07-02 02:29:21.674132         1217                 transit    4
#
#       distance_to_stopbar  distance_along_path  onmap_status  \
# ...

# %%
def travel_time(df):
    travel_time = df.groupby('temporaryId')
    traveltime = (pd.concat([travel_time.head(1), travel_time.tail(1)])
               .sort_values('temporaryId').sort_index()
               .reset_index(drop=True))
    traveltime['timestamp_verbose'] = pd.to_datetime(traveltime['timestamp_verbose'])
    traveltime['traveltime'] = traveltime['timestamp_verbose'].iloc[1::2] - traveltime['timestamp_verbose'].iloc[::2].to_numpy()
    df_traveltime = traveltime[np.arange(len(traveltime)) % 2 != 0]
    df_traveltime = df_traveltime[['temporaryId', 'traveltime','distance_along_path']]
    return df_traveltime.style.hide_index()

# %%
travel_time(df_bsm_pdx_broadway_try_1)
# Out:
# <style  type="text/css" >
# </style><table id="T_5361bb68_2853_11eb_ae24_a683e739990a" ><thead>    <tr>        <th class="col_heading level0 col0" >temporaryId</th>        <th class="col_heading level0 col1" >traveltime</th>        <th class="col_heading level0 col2" >distance_along_path</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_5361bb68_2853_11eb_ae24_a683e739990arow0_col0" class="data row0 col0" >26</td>
#                         <td id="T_5361bb68_2853_11eb_ae24_a683e739990arow0_col1" class="data row0 col1" >0 days 00:01:37.570266</td>
#                         <td id="T_5361bb68_2853_11eb_ae24_a683e739990arow0_col2" class="data row0 col2" >267.991</td>
#             </tr>
#             <tr>
#                                 <td id="T_5361bb68_2853_11eb_ae24_a683e739990arow1_col0" class="data row1 col0" >260</td>
# ...

# %%
travel_time(df_bsm_pdx_market10th_try_1)
# Out:
# <style  type="text/css" >
# </style><table id="T_53654b8e_2853_11eb_ae24_a683e739990a" ><thead>    <tr>        <th class="col_heading level0 col0" >temporaryId</th>        <th class="col_heading level0 col1" >traveltime</th>        <th class="col_heading level0 col2" >distance_along_path</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_53654b8e_2853_11eb_ae24_a683e739990arow0_col0" class="data row0 col0" >26</td>
#                         <td id="T_53654b8e_2853_11eb_ae24_a683e739990arow0_col1" class="data row0 col1" >0 days 00:00:08.274265</td>
#                         <td id="T_53654b8e_2853_11eb_ae24_a683e739990arow0_col2" class="data row0 col2" >110.722</td>
#             </tr>
#             <tr>
#                                 <td id="T_53654b8e_2853_11eb_ae24_a683e739990arow1_col0" class="data row1 col0" >56</td>
# ...

# %%
def haversine_in(lat1, lon1,lat2,lon2, to_radians=True, earth_radius=6371):
    """
    slightly modified version: of http://stackoverflow.com/a/29546836/2901002

    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees or in radians)

    All (lat, lon) coordinates must have numeric dtypes and be of equal length.

    """
    
    if to_radians:
        lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])

    a = np.sin((lat2-lat1)/2.0)**2 + \
        np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

    return earth_radius * 2 * np.arcsin(np.sqrt(a)) * 1000

# %%
total= haversine_in(45.51396909279303,-122.68508797973841,45.5131017118062,-122.68187913321353)

# %%
total
# Out:
# 267.98703169708614
